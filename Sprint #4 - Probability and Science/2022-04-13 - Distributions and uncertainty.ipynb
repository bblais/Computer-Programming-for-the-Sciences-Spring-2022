# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from sci378 import *
# Out:
# Version:  0.0.19

# %%
from scipy.stats import distributions as D

# %%
dist=D.norm
#dist=D.cauchy

# %%
x=linspace(0,10,100)
y=dist.pdf(x,loc=5,scale=1)
plot(x,y)

# %%
sample=dist.rvs(loc=5,scale=1,size=50)

# %%
sample
# Out:
# array([4.41848385, 5.72324808, 5.13271123, 5.32233117, 5.31920316,
#        6.07979234, 4.51782609, 5.32030533, 5.0422128 , 4.4449569 ,
#        5.07045262, 3.70199336, 5.05371378, 5.39592606, 4.96486383,
#        5.39650886, 5.76575038, 5.15747028, 6.95138686, 4.77278887,
#        5.18594751, 4.97468472, 3.6825405 , 4.62480752, 6.38843194,
#        4.56096814, 4.2731197 , 5.17744037, 4.45221281, 4.88987129,
#        5.84505786, 4.04579395, 4.58679019, 4.38535974, 4.68807687,
#        4.05993592, 5.95576664, 4.32047704, 4.57357596, 5.80501785,
#        4.20856358, 4.20589195, 4.27331222, 6.16671613, 5.85647875,
#        6.18963967, 4.6417234 , 2.93743118, 5.59056001, 5.66319775])

# %%
sample.mean()
# Out:
# 4.995226339489483

# %%
distribution_of_mean=dist.rvs(loc=5,scale=1/sqrt(len(sample)),size=(50,10000))

# %%
histogram(distribution_of_mean.mean(axis=0));

x=linspace(4.5,5.5,100)
y=dist.pdf(x,loc=5,scale=1/len(sample))
plot(x,y)
