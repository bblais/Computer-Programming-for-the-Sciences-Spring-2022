# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from mplturtle import *

# %%
def square(size):
    for i in range(4):
        forward(size)
        right(90)

# %%
reset()
square(50)

# %%
reset()
size=50
offset=20

for i in range(10):
    forward(offset)
    square(size)
    
    size=size+5
    offset=offset-2
