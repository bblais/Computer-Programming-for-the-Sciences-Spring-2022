# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from mplturtle import *

# %%
for i in range(3):
    forward(50)
    right(30)
    forward(60)
    left(30)
    
    penup()
    forward(100)
    pendown()

# %%
def worms():
    for i in range(3):
        forward(50)
        right(30)
        forward(60)
        left(30)

        penup()
        forward(100)
        pendown()

# %%
reset()
worms()

# %%
def worms2(N=3):
    for i in range(N):
        forward(50)
        right(30)
        forward(60)
        left(30)

        penup()
        forward(100)
        pendown()

# %%
reset()
worms2(5)
